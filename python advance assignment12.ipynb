# %% [markdown]
# Q1. Does assigning a value to a string's indexed character violate Python's string immutability?
#
# Yes, assigning a value to a string's indexed character violates Python's string immutability. Strings in Python are immutable, meaning their values cannot be changed after creation. If you try to assign a new value to a specific index in a string, it will result in a TypeError.
#
# Q2. Does using the += operator to concatenate strings violate Python's string immutability? Why or why not?
#
# No, using the += operator to concatenate strings does not violate Python's string immutability. While strings themselves are immutable, the += operation creates a new string that is the result of concatenation. The original strings remain unchanged, and the variable is reassigned to the new concatenated string.
#
# Q3. In Python, how many different ways are there to index a character?
#
# In Python, there is one primary way to index a character in a string using square brackets and an integer index. For example, my_string[0] retrieves the character at index 0. Additionally, negative indexing can be used to access characters from the end of the string (e.g., my_string[-1] for the last character).
#
# Q4. What is the relationship between indexing and slicing?
#
# Indexing and slicing are related concepts in Python strings:
#
# Indexing: Refers to retrieving an individual character at a specific position using an integer index.
#
# Slicing: Refers to extracting a substring from a string by specifying a range of indices. It involves specifying a start index, an end index, and an optional step.
#
# Q5. What is an indexed character's exact data type? What is the data form of a slicing-generated substring?
#
# The indexed character's exact data type is a string of length 1. It is a substring consisting of a single character.
# The data form of a slicing-generated substring is also a string, but its length may be greater than 1, depending on the specified range.
#
# Q6. What is the relationship between string and character "types" in Python?
#
# In Python, strings are sequences of characters. Each character in a string is a string of length 1. Therefore, there is no distinct "character" type; characters are represented as strings.
#
# Q7. Identify at least two operators and one method that allow you to combine one or more smaller strings to create a larger string.
#
# Operators:
#
# Concatenation Operator +: Concatenates two or more strings.
#
# Multiplication Operator *: Repeats a string multiple times.
#
# Method:
#
# join() Method: Joins a sequence of strings with a specified delimiter.
#
# Q8. What is the benefit of first checking the target string with in or not in before using the index method to find a substring?
#
# Checking with in or not in before using the index method helps avoid raising a ValueError if the substring is not present in the target string. It allows you to handle the presence or absence of the substring gracefully without causing the program to terminate unexpectedly.
#
# Q9. Which operators and built-in string methods produce simple Boolean (true/false) results?
#
# Operators:
#
# Comparison Operators (==, !=, <, >, <=, >=): Compare two strings and produce a Boolean result.
# Built-in String Methods:
#
# startswith(prefix): Returns True if the string starts with the specified prefix; otherwise, False.
#
# endswith(suffix): Returns True if the string ends with the specified suffix; otherwise, False.
#
# isalpha(): Returns True if all characters in the string are alphabetic; otherwise, False.
#
# isdigit(): Returns True if all characters in the string are digits; otherwise, False.
#
# islower(): Returns True if all alphabetic characters in the string are lowercase; otherwise, False.
#
# isupper(): Returns True if all alphabetic characters in the string are uppercase; otherwise, False.
