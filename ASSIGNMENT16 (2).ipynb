# %% [markdown]
# 1. Create a list called years_list, starting with the year of your birth, and each year thereafter until the year of your fifth birthday.
#    - sol. years_list = [1980, 1981, 1982, 1983, 1984, 1985]
#
# 2. In which year in years_list was your third birthday? Remember, you were 0 years of age for your first year.
#    - sol. third_birthday_year = years_list[3]
#      (third_birthday_year would be 1983.)
#
# 3. In the years list, which year were you the oldest?
#    - sol. oldest_year = years_list[-1]
#      (oldest_year would be 1985.)
#
# 4. Make a list called things with these three strings as elements: "mozzarella", "cinderella", "salmonella".
#    - sol. things = ["mozzarella", "cinderella", "salmonella"]
#
# 5. Capitalize the element in things that refers to a person and then print the list. Did it change the element in the list?
#    - sol. things[1] = things[1].capitalize()
#      print(things)
#      (This will print: ['mozzarella', 'Cinderella', 'salmonella']. It did change the element in the list.)
#
# 6. Make a surprise list with the elements "Groucho," "Chico," and "Harpo."
#    - sol. surprise = ["Groucho", "Chico", "Harpo"]
#
# 7. Lowercase the last element of the surprise list, reverse it, and then capitalize it.
#    - sol. surprise[-1] = surprise[-1].lower()[::-1].capitalize()
#      print(surprise)
#      (This will print: ['Groucho', 'Chico', 'Oprah'].)
#
# 8. Make an English-to-French dictionary called e2f and print it. Here are your starter words: dog is chien, cat is chat, and walrus is morse.
#    - sol. e2f = {"dog": "chien", "cat": "chat", "walrus": "morse"}
#      print(e2f)
#      (This will print the dictionary.)
#
# 9. Write the French word for walrus in your three-word dictionary e2f.
#    - sol. french_word_for_walrus = e2f["walrus"]
#      (french_word_for_walrus would be "morse.")
#
# 10. Make a French-to-English dictionary called f2e from e2f. Use the items method.
#    - sol. f2e = {french: english for english, french in e2f.items()}
#      print(f2e)
#      (This will print the French-to-English dictionary.)
#
# 11. Print the English version of the French word chien using f2e.
#    - sol. english_word_for_chien = f2e["chien"]
#      (english_word_for_chien would be "dog.")
#
# 12. Make and print a set of English words from the keys in e2f.
#    - sol. english_words_set = set(e2f.keys())
#      print(english_words_set)
#
# 13. Make a multilevel dictionary called life. Use these strings for the topmost keys: 'animals', 'plants', and 'other'.
#    - sol. life = { 'animals': { 'cats': ["Henri", "Grumpy", "Lucy"], 'octopi': {}, 'emus': {} }, 'plants': {}, 'other': {} }
#
# 14. Print the top-level keys of life.
#    - sol. top_level_keys = life.keys()
#      print(top_level_keys)
#
# 15. Print the keys for life['animals'].
#    - sol. animal_keys = life['animals'].keys()
#      print(animal_keys)
#
# 16. Print the values for life['animals']['cats']
#    - sol. cat_names = life['animals']['cats']
#      print(cat_names)
#      (This will print the list of cat names.)
