# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
#
# 2. What are the three different types of Boolean operators?
#
# 3. Make a list of each Boolean operator&#39;s truth tables (i.e. every possible combination of Boolean
# values for the operator and what it evaluate ).
#
# 4. What are the values of the following expressions?
# (5 &gt; 4) and (3 == 5)
# not (5 &gt; 4)
# (5 &gt; 4) or (3 == 5)
# not ((5 &gt; 4) or (3 == 5))
# (True and True) and (True == False)
# (not False) or (not True)
# 5. What are the six comparison operators?
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a
# condition and when you would use one.
#
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print(&#39;eggs&#39;)
# if spam &gt; 5:
# print(&#39;bacon&#39;)
# else:
# print(&#39;ham&#39;)
# print(&#39;spam&#39;)
# print(&#39;spam&#39;)
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints
# Greetings! if anything else is stored in spam.
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
#
# 10. How can you tell the difference between break and continue?
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent
# program that prints the numbers 1 to 10 using a while loop.
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after
# importing spam?

# %% [markdown]
# #1.
# The two values of the Boolean data type are True and False. You write them exactly as shown, with an uppercase 'T' and 'F'.
#
# #2.
# The three different types of Boolean operators are:
#
# AND (and)
# OR (or)
# NOT (not)
#
# #3.Truth tables for Boolean operators:
#
# AND (and):
#     True and True = True
# True and False = False
# False and True = False
# False and False = False
#
# OR (or):
#
#     True or True = True
# True or False = True
# False or True = True
# False or False = False
#
# NOT (not):
#
#     not True = False
# not False = True
#
# #4.
# Values of the following expressions:
#
# (5 > 4) and (3 == 5) - False
# not (5 > 4) - False
# (5 > 4) or (3 == 5) - True
# not ((5 > 4) or (3 == 5)) - False
# (True and True) and (True == False) - False
# (not False) or (not True) - True
#
#
# #5.
# The six comparison operators are:
#
# Equal to (==)
# Not equal to (!=)
# Greater than (>)
# Less than (<)
# Greater than or equal to (>=)
# Less than or equal to (<=)
#
# #6.
# The equal to (==) operator is used to compare two values for equality, while the assignment operator (=) is used to assign a value to a variable. You can differentiate them by context. For example:
#
# x = 5 assigns the value 5 to the variable x.
# if x == 5: checks if the value of x is equal to 5 in a conditional statement.
#
# #7.
# The three blocks in the provided code are:
#
# The first block assigns the value 0 to the variable spam.
# The second block is an if statement checking if spam is equal to 10. If true, it prints 'eggs'.
# The third block is nested within the second block and is an if statement checking if spam is greater than 5. If true, it prints 'bacon'. Otherwise, it prints 'ham'.
#
# #8.
# Here's code that prints messages based on the value stored in spam:
#
# if spam == 1:
#     print('Hello')
# elif spam == 2:
#     print('Howdy')
# else:
#     print('Greetings!')
#
# #9.
# If your program is stuck in an endless loop, you can typically press the Ctrl + C keys (Control key and C key) in most programming environments to forcefully terminate the program.
#
#
# #10.
# The break statement is used to exit a loop prematurely, while the continue statement is used to skip the rest of the current iteration and move to the next iteration of a loop.
#
# #11.
# In a for loop, range(10), range(0, 10), and range(0, 10, 1) are equivalent and will iterate from 0 to 9 (inclusive) with a step of 1.
#
# #12.
# program that prints the numbers 1 to 10 using both for and while loops:
#
# Using a for loop:
#
# for i in range(1, 11):
#     print(i)
# Using a while loop:
#
#
# i = 1
# while i <= 10:
#     print(i)
#     i += 1
#
#
# #13.
# If you have a function named bacon() inside a module named spam, you can call it after importing spam using the following syntax:
#
#
# import spam
# result = spam.bacon()
# This assumes that the bacon() function is defined in the spam module and can be accessed using dot notation.
